# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
np.random.seed(seed=42)

from collections import Counter

# %%
salestrain = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone3\\sales_train.csv')

# %%
items = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone3\\items.csv')

# %%
#ps4 item categories list
ps4 = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone3\\ps4console.csv')
ps4
# Out:
#       item_category_name  item_category_id
# 0  Игровые консоли - PS4                12

# %%
#Joining item_name and item_category_name using item_category_id
ps4info = pd.merge(items, ps4, on='item_category_id')
ps4info
# Out:
#                                             item_name  item_id  \
# 0          Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 1   Sony PlayStation 4 (500 Gb) Black (CUH-1008A/1...     6675
# 2   Sony PlayStation 4 (500 Gb) Black (CUH-1208A/B01)     6676
# 3       Sony PlayStation 4 (500 Gb) White (CUH-1108A)     6677
# 4   Sony PlayStation 4 (500 Gb) White (CUH-1208A/B01)     6678
# 5   Sony PlayStation 4 (500 Gb) Юбилейное издание ...     6679
# 6   Комплект Sony PS4 (500 Gb) Black (CUH-1108A/B0...    13440
# 7   Комплект Sony PS4 (500 Gb) Black (CUH-1108A/B0...    13441
# 8   Комплект Sony PS4 (500 Gb) Black (CUH-1108A/B0...    13442
# 9   Комплект Sony PS4 (500 Gb) Black (CUH-1108A/B0...    13443
# 10  Комплект Sony PS4 (500 Gb) Black (CUH-1108A/B0...    13444
# 11  Комплект Sony PlayStation 4 (1Tb) Black (CUH-1...    13445
# 12  Комплект Sony PlayStation 4 (1Tb) Black (CUH-1...    13446
# 13  Комплект Sony PlayStation 4 (1Tb) Black (CUH-1...    13447
# ...

# %%
#Joining item_name and item_category_name using item_id
ps4sales = pd.merge(ps4info, salestrain , on='item_id')
ps4sales
# Out:
#                                               item_name  item_id  \
# 0            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 1            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 2            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 3            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 4            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# ...                                                 ...      ...
# 7397  Комплект предзаказа на консоль Sony PlayStatio...    13532
# 7398  Комплект предзаказа на консоль Sony PlayStatio...    13532
# 7399  Комплект предзаказа на консоль Sony PlayStatio...    13532
# 7400  Комплект предзаказа на консоль Sony PlayStatio...    13532
# 7401  Комплект предзаказа на консоль Sony PlayStatio...    13532
#
#       item_category_id     item_category_name        date  date_block_num  \
# 0                   12  Игровые консоли - PS4  25.08.2015              31
# ...

# %%
ps4sales.describe()
# Out:
#             item_id  item_category_id  date_block_num      shop_id  \
# count   7402.000000            7402.0     7402.000000  7402.000000
# mean    8322.938530              12.0       19.870846    31.735882
# std     2907.283267               0.0        5.742087    16.561182
# min     6674.000000              12.0       10.000000     2.000000
# 25%     6675.000000              12.0       15.000000    18.000000
# 50%     6675.000000              12.0       20.000000    31.000000
# 75%     6677.000000              12.0       23.000000    46.000000
# max    13532.000000              12.0       33.000000    59.000000
#
#          item_price  item_cnt_day
# count   7402.000000   7402.000000
# mean   22889.299108      1.787355
# std     3768.189388      3.821714
# min      999.000000     -3.000000
# 25%    20191.000000      1.000000
# 50%    22990.000000      1.000000
# 75%    24990.000000      1.000000
# max    34990.000000    101.000000

# %%
ps42015 = ps4sales.query('date.str.contains("2015")', engine='python')
ps42015
# Out:
#                                               item_name  item_id  \
# 0            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 1            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 2            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 3            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# 4            Sony PlayStation 4 (1Tb) Black (CUH-1208B)     6674
# ...                                                 ...      ...
# 7397  Комплект предзаказа на консоль Sony PlayStatio...    13532
# 7398  Комплект предзаказа на консоль Sony PlayStatio...    13532
# 7399  Комплект предзаказа на консоль Sony PlayStatio...    13532
# 7400  Комплект предзаказа на консоль Sony PlayStatio...    13532
# 7401  Комплект предзаказа на консоль Sony PlayStatio...    13532
#
#       item_category_id     item_category_name        date  date_block_num  \
# 0                   12  Игровые консоли - PS4  25.08.2015              31
# ...

# %%
grouped.

# %%
ps42015.groupby('item_category_name')['item_price'].mean()
# Out:
# item_category_name
# Игровые консоли - PS4    26936.049696
# Name: item_price, dtype: float64
