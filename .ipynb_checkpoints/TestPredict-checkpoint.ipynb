# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
np.random.seed(seed=42)

from collections import Counter

# %%
salestrain = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone3\\sales_train.csv')
salestrain
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
#Original item categories list
itemscat = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone3\\item_categories.csv')
itemscat
# Out:
#            item_category_name  item_category_id
# 0     PC - Гарнитуры/Наушники                 0
# 1            Аксессуары - PS2                 1
# 2            Аксессуары - PS3                 2
# 3            Аксессуары - PS4                 3
# 4            Аксессуары - PSP                 4
# ..                        ...               ...
# 79                  Служебные                79
# 80         Служебные - Билеты                80
# 81    Чистые носители (шпиль)                81
# 82  Чистые носители (штучные)                82
# 83           Элементы питания                83
#
# [84 rows x 2 columns]

# %%
#Revised item categories list with data I need
revitemscat = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone3\\newitem_categories.csv', encoding='utf8')
revitemscat
# Out:
#                    item_category_name  item_category_id
# 0             PC - Гарнитуры/Наушники                 0
# 1                    Аксессуары - PS2                 1
# 2                    Аксессуары - PS3                 2
# 3                    Аксессуары - PS4                 3
# 4                    Аксессуары - PSP                 4
# 5                 Аксессуары - PSVita                 5
# 6               Аксессуары - XBOX 360                 6
# 7               Аксессуары - XBOX ONE                 7
# 8                      Билеты (Цифра)                 8
# 9                     Доставка товара                 9
# 10              Игровые консоли - PS2                10
# 11              Игровые консоли - PS3                11
# 12              Игровые консоли - PS4                12
# 13              Игровые консоли - PSP                13
# 14           Игровые консоли - PSVita                14
# 15         Игровые консоли - XBOX 360                15
# ...

# %%
items = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone3\\items.csv')
items
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# ...                                                  ...      ...
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id
# 0                    40
# 1                    76
# 2                    40
# 3                    40
# 4                    40
# ...

# %%
#Joining item_name and item_category_name using item_category_id
itemsandcat = pd.merge(items, revitemscat, on='item_category_id')
itemsandcat
# Out:
#                                               item_name  item_id  \
# 0                     007 Legends [PS3, русская версия]       27
# 1          2014 FIFA World Cup [PS3, английская версия]      948
# 2     2014 FIFA World Cup. Champion's Edition [PS3, ...      950
# 3     Adidas miCoach (только для PS Move) [PS3, англ...     1359
# 4     Air Conflicts: Pacific Carriers [РS3, русские ...     1372
# ...                                                 ...      ...
# 4386  Карта оплаты Windows: 2000 рублей [Цифровая ве...    13092
# 4387  Карта оплаты Windows: 250 рублей [Цифровая вер...    13093
# 4388  Карта оплаты Windows: 2500 рублей [Цифровая ве...    13094
# 4389  Карта оплаты Windows: 500 рублей [Цифровая вер...    13095
# 4390  Карта оплаты Windows: 750 рублей [Цифровая вер...    13096
#
#       item_category_id              item_category_name
# 0                   19                      Игры - PS3
# 1                   19                      Игры - PS3
# ...

# %%
#copying the first set of dateframes joined
ogrevitemsandcat = itemsandcat.copy()
ogrevitemsandcat
# Out:
#                                               item_name  item_id  \
# 0                     007 Legends [PS3, русская версия]       27
# 1          2014 FIFA World Cup [PS3, английская версия]      948
# 2     2014 FIFA World Cup. Champion's Edition [PS3, ...      950
# 3     Adidas miCoach (только для PS Move) [PS3, англ...     1359
# 4     Air Conflicts: Pacific Carriers [РS3, русские ...     1372
# ...                                                 ...      ...
# 4386  Карта оплаты Windows: 2000 рублей [Цифровая ве...    13092
# 4387  Карта оплаты Windows: 250 рублей [Цифровая вер...    13093
# 4388  Карта оплаты Windows: 2500 рублей [Цифровая ве...    13094
# 4389  Карта оплаты Windows: 500 рублей [Цифровая вер...    13095
# 4390  Карта оплаты Windows: 750 рублей [Цифровая вер...    13096
#
#       item_category_id              item_category_name
# 0                   19                      Игры - PS3
# 1                   19                      Игры - PS3
# ...

# %%
#Joining item_name and item_category_name using item_id
itemscatprice = pd.merge(itemsandcat, salestrain , on='item_id')
itemscatprice
# Out:
#                                                  item_name  item_id  \
# 0                        007 Legends [PS3, русская версия]       27
# 1                        007 Legends [PS3, русская версия]       27
# 2                        007 Legends [PS3, русская версия]       27
# 3                        007 Legends [PS3, русская версия]       27
# 4                        007 Legends [PS3, русская версия]       27
# ...                                                    ...      ...
# 1172675  Карта оплаты Windows: 2500 рублей [Цифровая ве...    13094
# 1172676  Карта оплаты Windows: 500 рублей [Цифровая вер...    13095
# 1172677  Карта оплаты Windows: 500 рублей [Цифровая вер...    13095
# 1172678  Карта оплаты Windows: 500 рублей [Цифровая вер...    13095
# 1172679  Карта оплаты Windows: 500 рублей [Цифровая вер...    13095
#
#          item_category_id              item_category_name        date  \
# 0                      19                      Игры - PS3  02.01.2013
# ...

# %%
itemscatprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1172680 entries, 0 to 1172679
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   item_name           1172680 non-null  object
#  1   item_id             1172680 non-null  int64
#  2   item_category_id    1172680 non-null  int64
#  3   item_category_name  1172680 non-null  object
#  4   date                1172680 non-null  object
#  5   date_block_num      1172680 non-null  int64
#  6   shop_id             1172680 non-null  int64
#  7   item_price          1172680 non-null  float64
#  8   item_cnt_day        1172680 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 89.5+ MB

# %%
itemscatprice.describe()
# Out:
#             item_id  item_category_id  date_block_num       shop_id  \
# count  1.172680e+06      1.172680e+06    1.172680e+06  1.172680e+06
# mean   5.828494e+03      2.373887e+01    1.471305e+01  3.230585e+01
# std    3.991683e+03      7.254863e+00    9.305515e+00  1.660293e+01
# min    2.700000e+01      0.000000e+00    0.000000e+00  0.000000e+00
# 25%    3.076000e+03      1.900000e+01    7.000000e+00  1.900000e+01
# 50%    4.904000e+03      2.300000e+01    1.400000e+01  3.100000e+01
# 75%    6.953000e+03      3.000000e+01    2.300000e+01  4.700000e+01
# max    2.216500e+04      3.600000e+01    3.300000e+01  5.900000e+01
#
#          item_price  item_cnt_day
# count  1.172680e+06  1.172680e+06
# mean   1.486796e+03  1.312300e+00
# std    2.483827e+03  3.424044e+00
# min   -1.000000e+00 -9.000000e+00
# 25%    4.980000e+02  1.000000e+00
# 50%    8.990000e+02  1.000000e+00
# 75%    1.749000e+03  1.000000e+00
# max    5.920000e+04  2.169000e+03

# %%
itemscatprice[(itemscatprice.item_category_id == '14') & (itemscatprice.item_category_id == '12')]
# Out:
# E:\miniconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [item_name, item_id, item_category_id, item_category_name, date, date_block_num, shop_id, item_price, item_cnt_day]
# Index: []

# %%
itemscatprice[(itemscatprice.item_category_id >= '14') & (itemscatprice.item_category_id >= '12')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-72a54967b1f2> in <module>
# ----> 1 itemscatprice[(itemscatprice.item_category_id >= '14') & (itemscatprice.item_category_id >= '12')]
#
# E:\miniconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# E:\miniconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# E:\miniconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     254
# ...

# %%
itemscatprice[itemscatprice.item_category_id == '14']
# Out:
# Empty DataFrame
# Columns: [item_name, item_id, item_category_id, item_category_name, date, date_block_num, shop_id, item_price, item_cnt_day]
# Index: []

# %%
itemscatprice1 = itemscatprice.query('item_category_id.str.contains("14")')
itemscatprice1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-9d592f92d7f4> in <module>
# ----> 1 itemscatprice1 = itemscatprice.query('item_category_id.str.contains("14")')
#       2 itemscatprice1
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# E:\miniconda3\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ...
